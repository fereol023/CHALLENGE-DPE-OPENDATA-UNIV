# %%
# !pip install mlflow
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import mlflow

mlflow.set_tracking_uri("../mlruns/")

# %%
# !mlflow server
# Out:
# /Users/tharse/projet-dpe/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [2025-02-26 14:48:33 +0100] [76739] [INFO] Starting gunicorn 23.0.0
# [2025-02-26 14:48:33 +0100] [76739] [INFO] Listening at: http://127.0.0.1:5000 (76739)
# [2025-02-26 14:48:33 +0100] [76739] [INFO] Using worker: sync
# [2025-02-26 14:48:33 +0100] [76740] [INFO] Booting worker with pid: 76740
# [2025-02-26 14:48:33 +0100] [76741] [INFO] Booting worker with pid: 76741
# /Users/tharse/projet-dpe/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...
